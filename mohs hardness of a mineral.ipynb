# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("train.csv")

# %%
test = pd.read_csv("test.csv")

# %%
sub = pd.read_csv("sample_submission.csv")

# %%
data.head(10)
# Out:
#    id  allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0   0               100.0       0.841611             10.000000       4.800000
# 1   1               100.0       7.558488             10.000000       4.800000
# 2   2                76.0       8.885992             15.600000       5.600000
# 3   3               100.0       8.795296             10.000000       4.800000
# 4   4               116.0       9.577996             11.600000       4.800000
# 5   5               131.0      24.529328             21.833333       4.666667
# 6   6                50.0       3.253996             10.000000       4.800000
# 7   7                30.0       2.701748              6.000000       4.000000
# 8   8               120.0      14.632000             12.000000       4.800000
# 9   9                97.0      13.477328             12.812500       5.000000
#
#    atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# ...

# %%
data[data.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [id, allelectrons_Total, density_Total, allelectrons_Average, val_e_Average, atomicweight_Average, ionenergy_Average, el_neg_chi_Average, R_vdw_element_Average, R_cov_element_Average, zaratio_Average, density_Average, Hardness]
# Index: []

# %%
data.shape
# Out:
# (10407, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10407 entries, 0 to 10406
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     10407 non-null  int64
#  1   allelectrons_Total     10407 non-null  float64
#  2   density_Total          10407 non-null  float64
#  3   allelectrons_Average   10407 non-null  float64
#  4   val_e_Average          10407 non-null  float64
#  5   atomicweight_Average   10407 non-null  float64
#  6   ionenergy_Average      10407 non-null  float64
#  7   el_neg_chi_Average     10407 non-null  float64
#  8   R_vdw_element_Average  10407 non-null  float64
#  9   R_cov_element_Average  10407 non-null  float64
#  10  zaratio_Average        10407 non-null  float64
#  11  density_Average        10407 non-null  float64
#  12  Hardness               10407 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 1.0 MB

# %%
data.describe()
# Out:
#                 id  allelectrons_Total  density_Total  allelectrons_Average  \
# count  10407.00000        10407.000000   10407.000000          10407.000000
# mean    5203.00000          128.053516      14.491342             17.033222
# std     3004.38646          224.123776      15.972877             10.468734
# min        0.00000            0.000000       0.000000              0.000000
# 25%     2601.50000           68.000000       7.558488             10.000000
# 50%     5203.00000          100.000000      10.650000             12.600000
# 75%     7804.50000          131.000000      16.676996             22.000000
# max    10406.00000        15300.000000     643.093804             67.000000
#
#        val_e_Average  atomicweight_Average  ionenergy_Average  \
# count   10407.000000          10407.000000       10407.000000
# mean        4.546789             37.507703          10.938308
# std         0.690864             26.012313           1.408276
# ...

# %%
data.nunique()[((data.nunique() == 1)|(data.nunique() == len(data)))]
# Out:
# id    10407
# dtype: int64

# %%
my_new_data = data.drop(['id'],axis=1)

# %%
my_new_data
# Out:
#        allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0                   100.0       0.841611             10.000000       4.800000
# 1                   100.0       7.558488             10.000000       4.800000
# 2                    76.0       8.885992             15.600000       5.600000
# 3                   100.0       8.795296             10.000000       4.800000
# 4                   116.0       9.577996             11.600000       4.800000
# ...                   ...            ...                   ...            ...
# 10402               128.0       7.558488             12.000000       4.000000
# 10403                30.0       1.743160             10.000000       5.333333
# 10404               196.0      30.920000             24.500000       5.500000
# 10405                38.0       1.553160             12.666667       4.666667
# 10406               288.0      24.655328             11.142857       4.571429
#
# ...

# %%
data.value_counts()
# Out:
# id     allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  atomicweight_Average  ionenergy_Average  el_neg_chi_Average  R_vdw_element_Average  R_cov_element_Average  zaratio_Average  density_Average  Hardness
# 0      100.0               0.841611       10.000000             4.800000       20.612526             11.088100          2.766000            1.732000               0.860000               0.496070         0.91457          6.0         1
# 6951   43.0                9.107996       11.300000             4.800000       24.808518             12.003400          2.828000            1.732000               0.864000               0.499196         1.08186          3.3         1
# 6933   46.0                9.133000       23.000000             4.000000       48.719500             9.877100           2.115000            1.900000               1.180000               0.478880         6.44467          2.0         1
# ...

# %%
x= my_new_data.drop(['Hardness'],axis=1)
y = my_new_data['Hardness']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
model = RandomForestRegressor()

# %%
model2 = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(x_test,y_test)
# Out:
# 0.4665356390683938

# %%
import numpy as np
np.random.seed()
for i in range(10,101,10):
    print(f'trying model with {i} estimator')
    model=RandomForestRegressor(n_estimators=i).fit(x_train,y_train)
    print(f'model accuracy on test:{model.score(x_test,y_test)*100:0.2f}%')
    print(' ')
# Out:
# trying model with 10 estimator
# model accuracy on test:41.07%
#
# trying model with 20 estimator
# model accuracy on test:44.49%
#
# trying model with 30 estimator
# model accuracy on test:45.92%
#
# trying model with 40 estimator
# model accuracy on test:44.60%
#
# trying model with 50 estimator
# model accuracy on test:45.20%
#
# trying model with 60 estimator
# model accuracy on test:46.07%
#
# trying model with 70 estimator
# model accuracy on test:46.29%
#
# trying model with 80 estimator
# model accuracy on test:46.40%
#
# trying model with 90 estimator
# model accuracy on test:46.62%
#
# trying model with 100 estimator
# model accuracy on test:46.50%

# %%
# print(train.isnull().values.any())
# print(test.isnull().values.any())

# %%
t = test.drop(['id'],axis=1)

# %%
sub["Hardness"]=model.predict(t)
sub.to_csv('submission.csv',index=False)
sub
# Out:
#          id  Hardness
# 0     10407    2.5970
# 1     10408    2.6860
# 2     10409    6.0340
# 3     10410    3.7820
# 4     10411    5.2535
# ...     ...       ...
# 6934  17341    5.2230
# 6935  17342    4.0000
# 6936  17343    4.7100
# 6937  17344    4.7300
# 6938  17345    2.8520
#
# [6939 rows x 2 columns]

# %%
test_ids = test['id']
submission_preds=model.predict(t)

# %%
df = pd.DataFrame({"ID_LAT_LON_YEAR_WEEK":test_ids.values,"emission":submission_preds})

# %%
df
# Out:
#       ID_LAT_LON_YEAR_WEEK  emission
# 0                    10407    2.5970
# 1                    10408    2.6860
# 2                    10409    6.0340
# 3                    10410    3.7820
# 4                    10411    5.2535
# ...                    ...       ...
# 6934                 17341    5.2230
# 6935                 17342    4.0000
# 6936                 17343    4.7100
# 6937                 17344    4.7300
# 6938                 17345    2.8520
#
# [6939 rows x 2 columns]

# %%
df.to_csv('submission2.csv',index=False)

# %%
sub["Hardness"]=model.predict(t)
sub.to_csv('submission.csv',index=False)
